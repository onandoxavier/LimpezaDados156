# %%
import pandas as pd

# %%
df_result = pd.DataFrame()

COLUNAS = [
    'SOLICITACAO',
	'TIPO',
	'ORGAO',
	'DATA_ASS',
	'HORARIO',
	'ASSUNTO',
	'SUBDIVISAO',
	'DESCRICAO',
	'LOGRADOURO_ASS',
	'CEP_ASS',
	'NUMERO_ASS',
	'BAIRRO_ASS',
	'REGIONAL_ASS',
	'MEIO_RESPOSTA',
	'OBSERVACAO',
	'SEXO',
	'BAIRRO_CIDADAO',
	'REGIONAL_CIDADAO',
	'DATA_NASC',
	'TIPO_CIDADAO',
	'ORGAO_RESP',
	'RESPOSTA_FINAL',
    'GEOM'
]
df_result = pd.DataFrame(columns=COLUNAS)

df = pd.read_csv('Resultado/inundacao156latlng.csv', sep=';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96853 entries, 0 to 96852
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SOLICITACAO       96853 non-null  int64
#  1   TIPO              96853 non-null  object
#  2   ORGAO             58421 non-null  object
#  3   DATA_ASS          96853 non-null  object
#  4   HORARIO           96853 non-null  object
#  5   ASSUNTO           96853 non-null  object
#  6   SUBDIVISAO        96853 non-null  object
#  7   DESCRICAO         96853 non-null  object
#  8   LOGRADOURO_ASS    96853 non-null  object
#  9   CEP_ASS           96853 non-null  int64
#  10  NUMERO_ASS        96853 non-null  int64
#  11  BAIRRO_ASS        96853 non-null  object
#  12  REGIONAL_ASS      96853 non-null  object
#  13  MEIO_RESPOSTA     96853 non-null  object
#  14  OBSERVACAO        41734 non-null  object
#  15  SEXO              96784 non-null  object
# ...

# %%
teste = df
teste = teste.dropna(subset=['RESPOSTA_FINAL'])
teste = teste[teste['RESPOSTA_FINAL'].apply(lambda x: not isinstance(x, float))]
#teste
teste[teste['RESPOSTA_FINAL'].apply(lambda x: len(x) >= 200)]
#df_resultado[df_resultado['REGIONAL_ASS'].apply(lambda x: isinstance(x, float))]
# Out:
#        SOLICITACAO         TIPO                               ORGAO  \
# 74938      6771104  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 74940      6729361  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 74942      6765916  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 74945      6767326  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 74949      6763515  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# ...            ...          ...                                 ...
# 96829      6475231  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 96838      6476881  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 96843      6509964  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 96847      6563384  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 96851      6482680  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
#
#          DATA_ASS   HORARIO                                  ASSUNTO  \
# 74938  06/02/2017  14:32:52                      CORREÇÃO GEOMÉTRICA
# ...

# %%
df = [df_resultado['REGIONAL_ASS'].apply(lambda x: isinstance(x, float))]
df[df['ORGAO'].apply(lambda x: len(x) >= 200)]
#df_resultado[df_resultado['REGIONAL_ASS'].apply(lambda x: isinstance(x, float))]

# %%
for index, row in df.iterrows():
    linha = {
        'SOLICITACAO':len(row['SOLICITACAO']),
        'TIPO':len(row['TIPO']),
        'ORGAO':len(row['ORGAO']),
        'DATA_ASS':len(row['DATA_ASS']),
        'HORARIO':len(row['HORARIO']),
        'ASSUNTO':len(row['ASSUNTO']),
        'SUBDIVISAO':len(row['SUBDIVISAO']),
        'DESCRICAO':len(row['DESCRICAO']),
        'LOGRADOURO_ASS':len(row['LOGRADOURO_ASS']),
        'CEP_ASS':len(row['CEP_ASS']),
        'NUMERO_ASS':len(row['NUMERO_ASS']),
        'BAIRRO_ASS':len(row['BAIRRO_ASS']),
        'REGIONAL_ASS':len(row['REGIONAL_ASS']),
        'MEIO_RESPOSTA':len(row['MEIO_RESPOSTA']),
        'OBSERVACAO':len(row['OBSERVACAO']),
        'SEXO':len(row['SEXO']),
        'BAIRRO_CIDADAO':len(row['BAIRRO_CIDADAO']),
        'REGIONAL_CIDADAO':len(row['REGIONAL_CIDADAO']),
        'DATA_NASC':len(row['DATA_NASC']),
        'TIPO_CIDADAO':len(row['TIPO_CIDADAO']),
        'ORGAO_RESP':len(row['ORGAO_RESP']),
        'RESPOSTA_FINAL':len(row['RESPOSTA_FINAL']),
        'GEOM':len(row['GEOM']),
        
    }
